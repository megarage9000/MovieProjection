# %%
import numpy as np
import pandas as pd
# nm1588970
data = pd.read_csv("title.basics.tsv.gz", sep='\t', na_values='\\N')
# Out:
# /home/megarage9000/source/repos/movieProjection/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8370243  tt9916848  tvEpisode              Episode #3.17
# 8370244  tt9916850  tvEpisode              Episode #3.19
# 8370245  tt9916852  tvEpisode              Episode #3.20
# 8370246  tt9916856      short                   The Wind
# 8370247  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                       Carmencita      0.0     1894.0      NaN
# 1           Le clown et ses chiens      0.0     1892.0      NaN
# 2                   Pauvre Pierrot      0.0     1892.0      NaN
# ...

# %%
newdata = data.groupby("titleType").agg("count")
newdata
# Out:
#                tconst  primaryTitle  originalTitle  isAdult  startYear  \
# titleType
# movie          592849        592849         592849   592849     517134
# short          839476        839476         839476   839476     816824
# tvEpisode     6146628       6146619        6146619  6146627    5250193
# tvMiniSeries    40462         40462          40462    40462      37994
# tvMovie        133548        133548         133548   133548     130075
# tvPilot             2             2              2        2          2
# tvSeries       215571        215571         215571   215571     200249
# tvShort         10359         10359          10359    10359      10262
# tvSpecial       34692         34692          34692    34692      34542
# video          327043        327043         327043   327043     325630
# videoGame       29618         29618          29618    29618      29157
#
#               endYear  runtimeMinutes   genres
# titleType
# ...

# %%
movies_only = data[(data["titleType"] == "movie") | (data["titleType"] == "tvMovie")]
movies_only
# Out:
#             tconst titleType  \
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 610      tt0000615     movie
# 625      tt0000630     movie
# ...            ...       ...
# 8370164  tt9916680     movie
# 8370169  tt9916692   tvMovie
# 8370176  tt9916706     movie
# 8370187  tt9916730     movie
# 8370198  tt9916754     movie
#
#                                               primaryTitle  \
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 610                                     Robbery Under Arms
# 625                                                 Hamlet
# ...                                                    ...
# 8370164  De la ilusión al desconcierto: cine colombiano...
# 8370169                    Teatroteka: Czlowiek bez twarzy
# 8370176                                    Dankyavar Danka
# ...

# %%
movies_only = movies_only.drop(columns = ["endYear", "titleType"])
rand = movies_only.groupby("startYear").agg("count")
rand
# Out:
#            tconst  primaryTitle  originalTitle  isAdult  runtimeMinutes  \
# startYear
# 1896.0          1             1              1        1               1
# 1897.0          1             1              1        1               0
# 1898.0          7             7              7        7               0
# 1899.0          8             8              8        8               1
# 1900.0          6             6              6        6               2
# ...           ...           ...            ...      ...             ...
# 2024.0         74            74             74       74               7
# 2025.0         12            12             12       12               2
# 2026.0          5             5              5        5               1
# 2027.0          5             5              5        5               1
# 2028.0          2             2              2        2               0
#
#            genres
# startYear
# 1896.0          1
# 1897.0          1
# 1898.0          7
# ...

# %%
t_consts = movies_only["tconst"].to_numpy()

# %%
t_consts
# Out:
# array(['tt0000502', 'tt0000574', 'tt0000591', ..., 'tt9916706',
#        'tt9916730', 'tt9916754'], dtype=object)

# %%
print(len(t_consts))
# Out:
# 726397

# %%
ratings_csv = pd.read_csv("title.ratings.tsv", sep='\t')
ratings_csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1818/4138789461.py in <module>
# ----> 1 ratings_csv = pd.read_csv("title.ratings.tsv", sep='\t')
#       2 ratings_csv
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ratings_csv = ratings_csv[ratings_csv["tconst"].isin(t_consts)]
ratings_csv

# %%
names_csv = pd.read_csv("name.basics.tsv.gz", sep='\t')
names_csv
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 11344946  nm9993714   Romeo del Rosario        \N        \N
# 11344947  nm9993716       Essias Loberg        \N        \N
# 11344948  nm9993717  Harikrishnan Rajan        \N        \N
# 11344949  nm9993718         Aayush Nair        \N        \N
# 11344950  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...
