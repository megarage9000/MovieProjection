# %%
import numpy as np
import pandas as pd
# nm1588970
data = pd.read_csv("title.basics.tsv.gz", sep='\t')
# Out:
# /home/megarage9000/source/repos/movieProjection/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8370243  tt9916848  tvEpisode              Episode #3.17
# 8370244  tt9916850  tvEpisode              Episode #3.19
# 8370245  tt9916852  tvEpisode              Episode #3.20
# 8370246  tt9916856      short                   The Wind
# 8370247  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8370243              Episode #3.17       0      2010      \N             \N
# 8370244              Episode #3.19       0      2010      \N             \N
# 8370245              Episode #3.20       0      2010      \N             \N
# 8370246                   The Wind       0      2015      \N             27
# 8370247  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8370243         Action,Drama,Family
# 8370244         Action,Drama,Family
# 8370245         Action,Drama,Family
# 8370246                       Short
# 8370247  Adventure,Animation,Comedy
#
# [8370248 rows x 9 columns]

# %%
newdata = data.groupby("titleType").agg("count")
newdata
# Out:
#                tconst  primaryTitle  originalTitle  isAdult  startYear  \
# titleType
# movie          592849        592849         592849   592849     592849
# short          839476        839476         839476   839476     839476
# tvEpisode     6146628       6146619        6146619  6146628    6146628
# tvMiniSeries    40462         40462          40462    40462      40462
# tvMovie        133548        133548         133548   133548     133548
# tvPilot             2             2              2        2          2
# tvSeries       215571        215571         215571   215571     215571
# tvShort         10359         10359          10359    10359      10359
# tvSpecial       34692         34692          34692    34692      34692
# video          327043        327043         327043   327043     327043
# videoGame       29618         29618          29618    29618      29618
#
#               endYear  runtimeMinutes   genres
# titleType
# movie          592849          592849   592849
# short          839476          839476   839476
# tvEpisode     6146628         6146628  6146618
# tvMiniSeries    40462           40462    40462
# tvMovie        133548          133548   133548
# tvPilot             2               2        2
# tvSeries       215571          215571   215571
# tvShort         10359           10359    10359
# tvSpecial       34692           34692    34692
# video          327043          327043   327043
# videoGame       29618           29618    29618

# %%
movies_only = data[(data["titleType"] == "movie") | (data["titleType"] == "tvMovie")]
movies_only
# Out:
#             tconst titleType  \
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 610      tt0000615     movie
# 625      tt0000630     movie
# ...            ...       ...
# 8370164  tt9916680     movie
# 8370169  tt9916692   tvMovie
# 8370176  tt9916706     movie
# 8370187  tt9916730     movie
# 8370198  tt9916754     movie
#
#                                               primaryTitle  \
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 610                                     Robbery Under Arms
# 625                                                 Hamlet
# ...                                                    ...
# 8370164  De la ilusión al desconcierto: cine colombiano...
# 8370169                    Teatroteka: Czlowiek bez twarzy
# 8370176                                    Dankyavar Danka
# 8370187                                             6 Gunn
# 8370198                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 610                                     Robbery Under Arms       0      1907
# 625                                                 Amleto       0      1908
# ...                                                    ...     ...       ...
# 8370164  De la ilusión al desconcierto: cine colombiano...       0      2007
# 8370169                    Teatroteka: Czlowiek bez twarzy       0      2015
# 8370176                                    Dankyavar Danka       0      2013
# 8370187                                             6 Gunn       0      2017
# 8370198                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# 610          \N             \N                       Drama
# 625          \N             \N                       Drama
# ...         ...            ...                         ...
# 8370164      \N            100                 Documentary
# 8370169      \N             66                       Drama
# 8370176      \N             \N                      Comedy
# 8370187      \N            116                          \N
# 8370198      \N             49                 Documentary
#
# [726397 rows x 9 columns]

# %%
movies_only = movies_only.drop(columns = ["endYear", "titleType"])
rand = movies_only.groupby("startYear").agg("count")
rand
# Out:
#            tconst  primaryTitle  originalTitle  isAdult  runtimeMinutes  \
# startYear
# 1905            1             1              1        1               1
# 1906            1             1              1        1               1
# 1907            2             2              2        2               2
# 1908            4             4              4        4               4
# 1909           29            29             29       29              29
# ...           ...           ...            ...      ...             ...
# 2025           12            12             12       12              12
# 2026            5             5              5        5               5
# 2027            5             5              5        5               5
# 2028            2             2              2        2               2
# \N          79188         79188          79188    79188           79188
#
#            genres
# startYear
# 1905            1
# 1906            1
# 1907            2
# 1908            4
# 1909           29
# ...           ...
# 2025           12
# 2026            5
# 2027            5
# 2028            2
# \N          79188
#
# [224 rows x 6 columns]

# %%
t_consts = movies_only["tconst"].to_numpy()

# %%
t_consts
# Out:
# array(['tt0000502', 'tt0000574', 'tt0000591', ..., 'tt9916706',
#        'tt9916730', 'tt9916754'], dtype=object)

# %%
print(len(t_consts))
# Out:
# 726397

# %%
ratings_csv = pd.read_csv("title.ratings.tsv", sep='\t')
ratings_csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2137/4138789461.py in <module>
# ----> 1 ratings_csv = pd.read_csv("title.ratings.tsv", sep='\t')
#       2 ratings_csv
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/source/repos/movieProjection/env/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'title.ratings.tsv'

# %%
ratings_csv = ratings_csv[ratings_csv["tconst"].isin(t_consts)]
ratings_csv
